# %%
import pandas as pd

# %%
# INPUTS
SEASON = '2024-2025'
LEAGUE_SLUG = 'Premier-League'

# %%
rolling_team_stats_path = f'../../data/features/team/rolling_team_stats_{SEASON}_{LEAGUE_SLUG}.parquet'

rolling_team_stats = pd.read_parquet(f'../../data/features/team/rolling_team_stats_{SEASON}_{LEAGUE_SLUG}.parquet')

# %%
rolling_team_stats
# Out:
#         team       date  shots_for_w3  shots_against_w3  sot_for_w3  \
# 0    Arsenal 2024-08-17           NaN               NaN         NaN
# 1    Arsenal 2024-08-24     18.000000          9.000000    6.000000
# 2    Arsenal 2024-08-31     13.500000         10.000000    5.000000
# 3    Arsenal 2024-09-15     12.666667         14.000000    5.666667
# 4    Arsenal 2024-09-22      9.000000         16.000000    5.000000
# ..       ...        ...           ...               ...         ...
# 755   Wolves 2025-04-26     13.000000          9.666667    4.333333
# 756   Wolves 2025-05-02     12.333333         10.000000    4.000000
# 757   Wolves 2025-05-10     10.000000          9.333333    2.333333
# 758   Wolves 2025-05-20     12.000000          7.333333    2.666667
# 759   Wolves 2025-05-25      9.333333          9.666667    2.000000
#
#      sot_against_w3  poss_for_w3  poss_against_w3  shots_per_poss_for_w3  \
# 0               NaN          NaN              NaN                    NaN
# ...

# %%
rolling_team_stats['shots_for_w3'].describe()
# Out:
# count    740.000000
# mean      12.825000
# std        3.690919
# min        3.000000
# 25%       10.333333
# 50%       12.416667
# 75%       15.000000
# max       26.000000
# Name: shots_for_w3, dtype: float64
