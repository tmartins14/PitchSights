# %%
import pandas as pd

# %%
# INPUTS
SEASON = '2024-2025'
LEAGUE_SLUG = 'Premier-League'

# %%
opponent_allowed_path = f'../../data/features/team/opponent_allowed_team_{SEASON}_{LEAGUE_SLUG}.parquet'

opponent_allowed = pd.read_parquet(opponent_allowed_path)

# %%
opponent_allowed
# Out:
#         team       date  allowed_shots_w3  allowed_sot_w3  \
# 0    Arsenal 2024-08-17               NaN             NaN
# 1    Arsenal 2024-08-24          9.000000        3.000000
# 2    Arsenal 2024-08-31         10.000000        3.000000
# 3    Arsenal 2024-09-15         14.000000        3.333333
# 4    Arsenal 2024-09-22         16.000000        4.000000
# ..       ...        ...               ...             ...
# 755   Wolves 2025-04-26          9.666667        2.666667
# 756   Wolves 2025-05-02         10.000000        2.333333
# 757   Wolves 2025-05-10          9.333333        1.666667
# 758   Wolves 2025-05-20          7.333333        1.333333
# 759   Wolves 2025-05-25          9.666667        4.333333
#
#      allowed_possession_w3  allowed_shots_per_poss_w3  allowed_sot_rate_w3  \
# 0                      NaN                        NaN                  NaN
# 1                47.000000                  19.148936             0.333333
# ...

# %%
opponent_allowed['allowed_shots_w3'].describe()
# Out:
# count    740.000000
# mean      12.825000
# std        3.828173
# min        3.000000
# 25%       10.000000
# 50%       12.666667
# 75%       15.333333
# max       27.333333
# Name: allowed_shots_w3, dtype: float64
