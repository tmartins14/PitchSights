# %%
import pandas as pd

# %%
team_ratings_path = '../../data/features/context/team_ratings_snapshots.parquet'

team_ratings = pd.read_parquet(team_ratings_path)

# %%
team_ratings
# Out:
#      asof_date        home_team        away_team  lambda_home  lambda_away  \
# 0   2024-08-16   Manchester Utd           Fulham          NaN          NaN
# 1   2024-08-17     Ipswich Town        Liverpool          NaN          NaN
# 2   2024-08-17    Newcastle Utd      Southampton          NaN          NaN
# 3   2024-08-17          Everton         Brighton          NaN          NaN
# 4   2024-08-17  Nott'ham Forest      Bournemouth          NaN          NaN
# ..         ...              ...              ...          ...          ...
# 375 2025-05-25  Nott'ham Forest          Chelsea     0.941521     1.451779
# 376 2025-05-25           Fulham  Manchester City     0.906342     1.993323
# 377 2025-05-25    Newcastle Utd          Everton     1.372870     1.560098
# 378 2025-05-25      Bournemouth   Leicester City     1.054467     0.938247
# 379 2025-05-25        Tottenham         Brighton     1.350429     0.951290
#
#      attack_home  defense_home  attack_away  defense_away  match_id
# ...

# %%
team_ratings['lambda_away'].describe()
# Out:
# count    370.000000
# mean       1.408862
# std        0.665514
# min        0.485090
# 25%        0.919776
# 50%        1.248119
# 75%        1.772354
# max        5.231999
# Name: lambda_away, dtype: float64
